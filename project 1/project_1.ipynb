# %% [markdown]
# <font size="12">DAV5400 Project 1: Chips of CPU and GPU </font>

# %% [markdown]
# <li><font size="4">Author:Zhengnan Li </font>
# <li><font size="4">Student Id: 800763534 </font>

# %% [markdown]
# In this project. I plan to use the dataset of chip of GPU and CPU to analyse the relationship between chip size, Process Size and frequency,etc. The dataset is found in heywhale and you can see it from here:
# [Chip of CPU and GPU](https://www.heywhale.com/mw/dataset/64dc9b5000151985794c41a9/content)

# %% [markdown]
# <font size="6">Intriduction </font>

# %% [markdown]
# In this project, I have chosen to work on a dataset on chips of CPU and GPU. This dataset consists of 4854 kinds of Product in different attributes. My research will be useful for those who are interested in chip devement situation. More precisely for the people who want to see summary of the currently chip and their size, performance, transistors and frequency etc. So they can know the relationship between different product and attributes, Which benefits a lot because the customer can choose the product suitable for them and the developer can figure out what they need to improve.
#
# The purpose of the analysis are as followes:
# <ol>
# <li>  Observe the product number of different vendors
# <li>  Observe the influences of chip process size to Frequency
# <li>  Observe the relationship between transister and frequency

# %% [markdown]
# <font size="6">Data Summary </font>

# %% [markdown]
# **We will use the package as follows**
# <li>Pandas: Data manipulation and analysis library.
# <li>Numpy: Numerical computing library.
# <li>Matplotlib: Data visualization library.
# <li>Seaborn: Statistical data visualization library.

# %%
from Part_1 import Solution
#Put my own path here
my_file_path = '/Users/lizhengnan/Documents/pandas_project/chip_dataset.csv'
obj = Solution (my_file_path)

# %% [markdown]
# **View the table we have**

# %%
obj.a()
# Out:
#                    Product Type Release_Date  Process_Size    TDP  Die_Size  \
# 0      AMD Athlon 64 3500+  CPU      2/20/07          65.0   45.0      77.0
# 1         AMD Athlon 200GE  CPU       9/6/18          14.0   35.0     192.0
# 2     Intel Core i5-1145G7  CPU       9/2/20          10.0   28.0       NaN
# 3    Intel Xeon E5-2603 v2  CPU       9/1/13          22.0   80.0     160.0
# 4  AMD Phenom II X4 980 BE  CPU       5/3/11          45.0  125.0     258.0
#
#    Transistors  Freq Vendor
# 0        122.0  2200    AMD
# 1       4800.0  3200    AMD
# 2          NaN  2600  Intel
# 3       1400.0  1800  Intel
# 4        758.0  3700    AMD

# %% [markdown]
# For this project I acquired the dataset from heywhale. The use case of the dataset as follows:
# According to the website, the attributes of the data as follows:
# <ol>
# <li>Product: Description of the products.
# <li>Type: Classfication of CPU and GPU.
# <li>Release Date:The date of the product publish.
# <li>Process Size (nm): The size of the features (the elements that make up the transistors)
# <li>TDP (W):
# Thermal design power is defined as the theoretical maximum amount of heat generated by a CPU or GPU
# <li>Die Size: The die size of a specific chip is the physical dimensions of a bare die
# <li>Transistors: tiny electronic switches that can be turned on or off by applying a voltage to their terminals.
# <li>Freq: The clock rate of a CPU is normally determined by the frequency of an oscillator crystal.
# <li>Vendor:The company to produce the chip

# %% [markdown]
# **Data type are as follows:**
# <li>Product:object
# <li>Type:object
# <li>Type:
# <li>Release Date:object
# <li>Process Size (nm):float(64)
# <li>TDP (W):float(64)
# <li>Die Size (mm^2):float(64)
# <li>Transistors (million):float(64)
# <li>Freq (MHz): int(64)
# <li>Vendor:object

# %% [markdown]
# **Data Preparation-Null values**

# %% [markdown]
# According to the website there are some negative values present in the dataset which represents NaN values. We have decided to remove the rows comprised with negative values. This is because negative values will impact on our research results negatively, we are against of letting the entire analysis suffered from some negative values. We understand that removing those rows with negative values will restrict us from the analysis of some of the products, however, we will be able to produce accurate analysis for rest of the products.

# %% [markdown]
# Now we will check if there is any null value present in the dataset

# %%
obj.b()
# Out:
# Product           0
# Type              0
# Release_Date      0
# Process_Size      9
# TDP             626
# Die_Size        715
# Transistors     711
# Freq              0
# Vendor            0
# dtype: int64

# %% [markdown]
# It appears the TDP column, Die Size column and Transistors column contains null values that we required to remove to conduct unbiased research and reach to the right answers of each of the research question.In order to remove the null values we use dropna function.

# %%
obj.c()
# Out:
#                             Product Type Release_Date  Process_Size    TDP  \
# 0               AMD Athlon 64 3500+  CPU      2/20/07          65.0   45.0
# 1                  AMD Athlon 200GE  CPU       9/6/18          14.0   35.0
# 3             Intel Xeon E5-2603 v2  CPU       9/1/13          22.0   80.0
# 4           AMD Phenom II X4 980 BE  CPU       5/3/11          45.0  125.0
# 5             Intel Xeon E5-2470 v2  CPU       9/1/13          22.0   95.0
# ...                             ...  ...          ...           ...    ...
# 4844              ATI FirePro V7800  GPU      4/26/10          40.0  150.0
# 4845             NVIDIA Tegra 3 GPU  GPU      11/9/11          40.0   20.0
# 4846  NVIDIA Playstation 3 GPU 28nm  GPU       6/3/13          28.0   21.0
# 4849            NVIDIA Quadro 3000M  GPU      2/22/11          40.0   75.0
# 4851         NVIDIA GeForce GT 320M  GPU       3/3/10          40.0   23.0
#
#       Die_Size  Transistors  Freq  Vendor
# ...

# %% [markdown]
# <font size="6"> Exploratory Data Analysis </font>

# %% [markdown]
# **In this stage, we will perform exploratory data analysis on the above dataset to answer the above research questions**

# %% [markdown]
# **Observe the product number of different vendor**

# %%
from Part_2 import Solution
#Use seaborn to visualize the results
obj.task_two()

# %% [markdown]
# **observe the data of Process Size**

# %%
obj.task_d()
# Out:
# /Users/lizhengnan/Documents/pandas_project/Part_1.py:163: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=self.df, x=self.df.index, y='Process_Size', palette='Set3')

# %% [markdown]
# **observe the data of TDB**

# %%
obj.task_e()
# Out:
# /Users/lizhengnan/Documents/pandas_project/Part_1.py:176: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=self.df, x=self.df.index, y='TDP', palette='Set3')

# %% [markdown]
# **observe the data of Die size**

# %%
obj.task_f()
# Out:
# /Users/lizhengnan/Documents/pandas_project/Part_1.py:189: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=self.df, x=self.df.index, y='Die_Size', palette='Set3')

# %% [markdown]
# **observe the data of Transistors**

# %%
obj.task_g()
# Out:
# /Users/lizhengnan/Documents/pandas_project/Part_1.py:202: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=self.df, x=self.df.index, y='Transistors', palette='Set3')

# %% [markdown]
# **observe the data of frequency**

# %%
obj.task_h()
# Out:
# /Users/lizhengnan/Documents/pandas_project/Part_1.py:215: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=self.df, x=self.df.index, y='Freq', palette='Set3')

# %% [markdown]
# <font size="6"> Inference </font>

# %% [markdown]
# **Observe the influences of chip process size to Frequency**

# %%
from Part_3 import Solution
#use matplotlib to show the relationship
obj.task_five()

# %%
#use seaborn to show the relationship
obj.task_six()

# %% [markdown]
# We can see that the smaller the process size is, the chip will have higher process frequency.

# %% [markdown]
# **Observe the relationship between transister and frequency**

# %%
#use matplotlib to show the relationship
obj.task_seven()

# %% [markdown]
# We can see from the chart that the less the transistors chip has, the frequency is more high.

# %%
#use seaborn to show the relationship
obj.task_eight()

# %% [markdown]
# **Observe the relationship between die size and frequency.**

# %%
#use matplotlib to show the relationship
obj.task_nine()

# %%
#use seaborn to show the relationship
obj.task_ten()

# %% [markdown]
# We can see that the smaller Die size is, the frequency will be higher. Although some data show high frequency, which may be due to the influence of other factors, there are still overall trends and patterns.

# %% [markdown]
# <font size="6"> Conclusion </font>

# %% [markdown]
# The purpose of this research was to inform about the different types of chip by different vendors and attributes.From this research it can be stated that.From the above analysis, we can see that in general, Intel's CPUs and Nvida's GPUs have more overall products, which means that they are very competitive in their respective fields. In addition to the first time, the running speed of the chip is strongly related to various aspects and affects each other. Generally speaking, the smaller the size of the chip processing technology, the smaller the number of transistors, the smaller the chip die, and the faster the chip frequency. We can summarize our future research directions for chips.

# %% [markdown]
# <font size="6"> References </font>

# %% [markdown]
# <li>https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
# <li>https://seaborn.pydata.org/index.html
